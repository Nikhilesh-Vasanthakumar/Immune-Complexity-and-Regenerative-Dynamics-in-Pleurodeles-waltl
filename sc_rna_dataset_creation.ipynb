# %%
import scanpy as sc
import pandas as pd
import tarfile
import gzip
from io import BytesIO
from concurrent.futures import ThreadPoolExecutor

# Path to your .tar file
tar_file_path = '/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW.tar'

# Path to your Excel sheet
excel_file_path = '/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/Supplementary.xlsx'

# Function to read gzipped text content
def read_gzipped_text(file):
    with gzip.open(file, 'rt') as f:
        content = f.read()
    return content

# Load tissue_barcode info from the Excel sheet
tissue_barcode_df = pd.read_excel(excel_file_path)

# Create an empty DataFrame to store counts data
counts_df = pd.DataFrame()

# Function to load counts from a gzipped text file
def load_counts(member, tar):
    gzipped_content = tar.extractfile(member).read()
    member_counts_df = pd.read_csv(BytesIO(gzip.decompress(gzipped_content)), sep='\t', index_col=0)
    return member_counts_df.T

# Load counts from the .tar file using ThreadPoolExecutor
with tarfile.open(tar_file_path, 'r') as tar:
    with ThreadPoolExecutor(max_workers=4) as executor:
        # List of future objects for parallel execution
        futures = [executor.submit(load_counts, member, tar) for member in tar.getmembers() if member.name.endswith('.txt.gz')]
        
        # Extract results from futures as they complete
        for future in futures:
            member_counts_df = future.result()
            counts_df = counts_df.append(member_counts_df)

# Reset the index of the counts DataFrame
counts_df.reset_index(drop=True, inplace=True)

# Create an AnnData object for Scanpy
adata = sc.AnnData(X=counts_df.values, obs=tissue_barcode_df)
# Now you can perform various analyses using Scanpy on the 'adata' object
# For example, you can perform clustering, dimensionality reduction, etc.

# Save the AnnData object to a file if needed
#sc.write('your_output.h5ad', adata)
# Out:
# KeyboardInterrupt

# %%
import scanpy as sc
import pandas as pd
import tarfile
import gzip
from io import BytesIO
from concurrent.futures import ThreadPoolExecutor
from pathlib import Path

# Path to the extracted folder containing individual count files
extracted_folder_path = '/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201445_RAW'

# Path to the Excel sheet
excel_file_path = '/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/Supplementary.xlsx'

# Function to read gzipped text content
def read_gzipped_text(file):
    with gzip.open(file, 'rt') as f:
        content = f.read()
    return content

# Load tissue_barcode info from the Excel sheet
tissue_barcode_df = pd.read_excel(excel_file_path)

# Create an empty DataFrame to store counts data
counts_df = pd.DataFrame()

# Function to load counts from a gzipped text file
def load_counts(file_path):
    # Extract the sample ID from the file name
    sample_id = file_path.stem
    
    # Read the gzipped content into a DataFrame
    member_counts_df = pd.read_csv(BytesIO(gzip.decompress(read_gzipped_text(file_path))), sep='\t', index_col=0)
    
    # Transpose the DataFrame to have samples as columns
    member_counts_df = member_counts_df.T
    
    # Add a column for the sample ID
    member_counts_df['SampleID'] = sample_id
    
    return member_counts_df


# Load counts from individual files in the extracted folder using ThreadPoolExecutor
with ThreadPoolExecutor(max_workers=4) as executor:
    # List of future objects for parallel execution
    futures = [executor.submit(load_counts, file_path) for file_path in Path('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201445_RAW').glob('*.txt.gz')]
    print(futures)
    # Extract results from futures as they complete
    for future in futures:
        member_counts_df = future.result()
        counts_df = counts_df.append(member_counts_df)

# Reset the index of the counts DataFrame
counts_df.reset_index(drop=True, inplace=True)

# Create an AnnData object for Scanpy
adata = sc.AnnData(X=counts_df.values[:, :-1], obs=tissue_barcode_df)

# Now you can perform various analyses using Scanpy on the 'adata' object
# For example, you can perform clustering, dimensionality reduction, etc.

# Save the AnnData object to a file if needed
#sc.write('your_output.h5ad', adata)
# Out:
# []
# /home/nikvaku/.local/lib/python3.9/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 58
#      55 counts_df.reset_index(drop=True, inplace=True)
#      57 # Create an AnnData object for Scanpy
# ---> 58 adata = sc.AnnData(X=counts_df.values[:, :-1], obs=tissue_barcode_df)
#      60 # Now you can perform various analyses using Scanpy on the 'adata' object
#      61 # For example, you can perform clustering, dimensionality reduction, etc.
#      62
#      63 # Save the AnnData object to a file if needed
#      64 #sc.write('your_output.h5ad', adata)
#
# File ~/.local/lib/python3.9/site-packages/anndata/_core/anndata.py:291, in AnnData.__init__(self, X, obs, var, uns, obsm, varm, layers, raw, dtype, shape, filename, filemode, asview, obsp, varp, oidx, vidx)
#     289     self._init_as_view(X, oidx, vidx)
#     290 else:
# --> 291     self._init_as_actual(
#     292         X=X,
#     293         obs=obs,
#     294         var=var,
#     295         uns=uns,
#     296         obsm=obsm,
#     297         varm=varm,
#     298         raw=raw,
#     299         layers=layers,
#     300         dtype=dtype,
#     301         shape=shape,
#     302         obsp=obsp,
#     303         varp=varp,
#     304         filename=filename,
#     305         filemode=filemode,
#     306     )
#
# File ~/.local/lib/python3.9/site-packages/anndata/_core/anndata.py:511, in AnnData._init_as_actual(self, X, obs, var, uns, obsm, varm, varp, obsp, raw, layers, dtype, shape, filename, filemode)
#     508 # Backwards compat for connectivities matrices in uns["neighbors"]
#     509 _move_adj_mtx({"uns": self._uns, "obsp": self._obsp})
# --> 511 self._check_dimensions()
#     512 self._check_uniqueness()
#     514 if self.filename:
#
# File ~/.local/lib/python3.9/site-packages/anndata/_core/anndata.py:1853, in AnnData._check_dimensions(self, key)
#    1851     key = {key}
#    1852 if "obs" in key and len(self._obs) != self._n_obs:
# -> 1853     raise ValueError(
#    1854         "Observations annot. `obs` must have number of rows of `X`"
#    1855         f" ({self._n_obs}), but has {self._obs.shape[0]} rows."
#    1856     )
#    1857 if "var" in key and len(self._var) != self._n_vars:
#    1858     raise ValueError(
#    1859         "Variables annot. `var` must have number of columns of `X`"
#    1860         f" ({self._n_vars}), but has {self._var.shape[0]} rows."
#    1861     )
#
# ValueError: Observations annot. `obs` must have number of rows of `X` (0), but has 299 rows.

# %%
import pandas as pd

# Specify the correct sheet name or index
sheet_name = 'Tissue barcode'  # Replace with the actual sheet name

# Read the Excel file
try:
    df = pd.read_excel('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_Supplementary_Table_Tissue_barcode_seq_mode_v2.xlsx', sheet_name=sheet_name)
    # Now you can work with the DataFrame 'df'
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# An error occurred: File is not a zip file

# %%
from pathlib import Path
import pandas as pd

file_path = Path("/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/Supplementary.xlsx")
file_extension = file_path.suffix.lower()[1:]

if file_extension == 'xlsx':
    df = pd.read_excel(file_path, engine='openpyxl')
elif file_extension == 'xls':
    df = pd.read_excel(file_path)
elif file_extension == 'csv':
    df = pd.read_csv(file_path)
else:
    raise Exception("File not supported")

# %%
tissue_barcode_df
# Out:
#        Tissue barcode base Tissue barcode Base location  Unnamed: 2  \
# 0                NEO1,NEO2                  Read1:42-51         NaN
# 1    NEO3,NEO4,META1,META2                  Read1:19-28         NaN
# 2                      NaN                          NaN         NaN
# 3                      NaN                          NaN         NaN
# 4                      NaN                          NaN         NaN
# ..                     ...                          ...         ...
# 294                    NaN                          NaN         NaN
# 295                    NaN                          NaN         NaN
# 296                    NaN                          NaN         NaN
# 297                    NaN                          NaN         NaN
# 298                    NaN                          NaN         NaN
#
#                  Unnamed: 3 Tissue barcode Tissue barcode.1 Tissue barcode.2  \
# 0                     Batch          Brain             Lung  Cloacal chamber
# 1          Neotenic_1(NEO1)     AACTGCTGCC       GGAGCGGCCG       AACTGCTGCC
# 2          Neotenic_1(NEO1)     TGCGCGATGC       CGCGTACGAC       TGCGCGATGC
# 3          Neotenic_1(NEO1)     ATTGAGATTG       CGATGGCGCC       ATTGAGATTG
# 4          Neotenic_1(NEO1)     TTGATATATT       TGGTATTCAT       TTGATATATT
# ..                      ...            ...              ...              ...
# 294  Metamorphosed_2(META2)     CGAATAATTC              NaN              NaN
# 295  Metamorphosed_2(META2)     GCGACGCCTT              NaN              NaN
# 296  Metamorphosed_2(META2)     ATCAACGATT              NaN              NaN
# 297  Metamorphosed_2(META2)     GTTCTGAATT              NaN              NaN
# 298  Metamorphosed_2(META2)     GCTAACCTCA              NaN              NaN
#
#     Tissue barcode.3 Tissue barcode.4 Tissue barcode.5  ... Tissue barcode.8  \
# 0              Liver        Intestine          Stomach  ...            Heart
# 1         GAAGGTTGCC       GCGCGGTAGT       AGACTCAAGC  ...       GGATGCAGCA
# 2         GTTGAAGGAT       CTGGATTAGT       GCAGGCGACG  ...       CCGCTATATT
# 3         TGCGCCAGAA       TTGGATCCTT       AATACTCTTC  ...       ATCGAGTCGC
# 4         CGAATAATTC       TTGGAATCTC       CCAACTAACC  ...       GCGACGCAGA
# ..               ...              ...              ...  ...              ...
# 294              NaN              NaN              NaN  ...              NaN
# 295              NaN              NaN              NaN  ...              NaN
# 296              NaN              NaN              NaN  ...              NaN
# 297              NaN              NaN              NaN  ...              NaN
# 298              NaN              NaN              NaN  ...              NaN
#
#     Tissue barcode.9 Tissue barcode.10 Tissue barcode.11 Tissue barcode.12  \
# 0                Eye            Kidney            Spleen              Skin
# 1         TATTACTCAT        GAACTGCATC        GGAGCGGCCG        TTACGTATAC
# 2         AACTGATCTT        ACTCTCTCAA        CGCGTACGAC        ACTTAACTAG
# 3         CCGCGGACCG        GTCGCTCAGT        CGATGGCGCC        GCAGACCGGT
# 4         AATACGCAGG        CCGTCGGAGG        TGGTATTCAT        TGAGTCCAGA
# ..               ...               ...               ...               ...
# 294              NaN        TTGGAATCTC               NaN               NaN
# 295              NaN        ACCTGGACGC               NaN               NaN
# 296              NaN        GCGTTCAGCT               NaN               NaN
# 297              NaN        TTAGCAATAA               NaN               NaN
# 298              NaN        TTGATGCTAT               NaN               NaN
#
#     Tissue barcode.13 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21
# 0                Gill         NaN         NaN         NaN         NaN
# 1          CGGATGAAGG         NaN         NaN         NaN         NaN
# 2          TATCGTCGGC         NaN         NaN         NaN         NaN
# 3          GCCGTATGCT         NaN         NaN         NaN         NaN
# 4          CTGAACTGGT         NaN         NaN         NaN         NaN
# ..                ...         ...         ...         ...         ...
# 294               NaN         NaN         NaN         NaN         NaN
# 295               NaN         NaN         NaN         NaN         NaN
# 296               NaN         NaN         NaN         NaN         NaN
# 297               NaN         NaN         NaN         NaN         NaN
# 298               NaN         NaN         NaN         NaN         NaN
#
# [299 rows x 22 columns]

# %%
result = load_counts('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 result = load_counts('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/')
#
# Cell In[19], line 30, in load_counts(file_path)
#      28 def load_counts(file_path):
#      29     # Extract the sample ID from the file name
# ---> 30     sample_id = file_path.stem
#      32     # Read the gzipped content into a DataFrame
#      33     member_counts_df = pd.read_csv(BytesIO(gzip.decompress(read_gzipped_text(file_path))), sep='\t', index_col=0)
#
# AttributeError: 'str' object has no attribute 'stem'

# %%
result = load_counts(Path('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6063999_NEO1_1_count.txt.gz'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 result = load_counts(Path('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6063999_NEO1_1_count.txt.gz'))
#
# Cell In[35], line 33, in load_counts(file_path)
#      30 sample_id = file_path.stem
#      32 # Read the gzipped content into a DataFrame
# ---> 33 member_counts_df = pd.read_csv(BytesIO(gzip.decompress(read_gzipped_text(file_path))), sep='\t', index_col=0)
#      35 # Transpose the DataFrame to have samples as columns
#      36 member_counts_df = member_counts_df.T
#
# File /usr/lib64/python3.9/gzip.py:555, in decompress(data)
#     551 def decompress(data):
#     552     """Decompress a gzip compressed string in one shot.
#     553     Return the decompressed string.
#     554     """
# --> 555     with GzipFile(fileobj=io.BytesIO(data)) as f:
#     556         return f.read()
#
# TypeError: a bytes-like object is required, not 'str'

# %%
files = list(Path('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW').glob('*.txt.gz'))

# %%
files
# Out:
# [PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064093_NEO1_95_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064567_META1_46_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064336_NEO2_141_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064532_META1_11_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064036_NEO1_38_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064500_NEO4_74_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064007_NEO1_9_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064024_NEO1_26_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064493_NEO4_67_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064381_NEO3_3_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064314_NEO2_119_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064231_NEO2_36_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064331_NEO2_136_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064473_NEO4_47_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064152_NEO1_154_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064020_NEO1_22_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064422_NEO3_44_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064174_NEO1_176_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064040_NEO1_42_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064509_NEO4_83_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064307_NEO2_112_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064360_NEO2_165_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064593_META2_16_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064348_NEO2_153_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064514_NEO4_88_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064052_NEO1_54_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064368_NEO2_173_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064347_NEO2_152_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064468_NEO4_42_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064153_NEO1_155_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064472_NEO4_46_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064123_NEO1_125_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064538_META1_17_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064392_NEO3_14_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064224_NEO2_29_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064291_NEO2_96_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064441_NEO4_15_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064284_NEO2_89_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064034_NEO1_36_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064505_NEO4_79_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064186_NEO1_188_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064458_NEO4_32_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064542_META1_21_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064244_NEO2_49_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064159_NEO1_161_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064227_NEO2_32_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064326_NEO2_131_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064583_META2_6_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064592_META2_15_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064548_META1_27_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064377_NEO2_182_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064260_NEO2_65_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064302_NEO2_107_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064338_NEO2_143_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064245_NEO2_50_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064586_META2_9_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064115_NEO1_117_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064272_NEO2_77_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064037_NEO1_39_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064258_NEO2_63_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064132_NEO1_134_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064612_3T3_3.dge.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064494_NEO4_68_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064190_NEO1_192_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064333_NEO2_138_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064497_NEO4_71_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064105_NEO1_107_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064522_META1_1_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064380_NEO3_2_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064469_NEO4_43_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064203_NEO2_8_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064146_NEO1_148_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064417_NEO3_39_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064535_META1_14_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064450_NEO4_24_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064511_NEO4_85_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6064069_NEO1_71_count.txt.gz'),
#  PosixPath('/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW/GSM6
home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/Supplementary.xlsx'

# Load counts from the .tar file
with tarfile.open(tar_file_path, 'r') as tar:
    # Assuming the counts file is named 'counts.csv' within the tar archive
    counts_csv = tar.extractfile('counts.csv')

    # Load counts into a pandas DataFrame
    counts_df = pd.read_csv(counts_csv)

# Load tissue_barcode info from the Excel sheet
tissue_barcode_df = pd.read_excel(excel_file_path)

# Create an AnnData object for Scanpy
adata = sc.AnnData(X=counts_df.values.T, obs=tissue_barcode_df)

# Now you can perform various analyses using Scanpy on the 'adata' object
# For example, you can perform clustering, dimensionality reduction, etc.

# Save the AnnData object to a file if needed
#sc.write('your_output.h5ad', adata)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 15
#      12 # Load counts from the .tar file
#      13 with tarfile.open(tar_file_path, 'r') as tar:
#      14     # Assuming the counts file is named 'counts.csv' within the tar archive
# ---> 15     counts_csv = tar.extractfile('counts.csv')
#      17     # Load counts into a pandas DataFrame
#      18     counts_df = pd.read_csv(counts_csv)
#
# File /usr/lib64/python3.9/tarfile.py:2113, in TarFile.extractfile(self, member)
#    2110 self._check("r")
#    2112 if isinstance(member, str):
# -> 2113     tarinfo = self.getmember(member)
#    2114 else:
#    2115     tarinfo = member
#
# File /usr/lib64/python3.9/tarfile.py:1799, in TarFile.getmember(self, name)
#    1797 tarinfo = self._getmember(name.rstrip('/'))
#    1798 if tarinfo is None:
# -> 1799     raise KeyError("filename %r not found" % name)
#    1800 return tarinfo
#
# KeyError: "filename 'counts.csv' not found"

# %%
import scanpy as sc
import pandas as pd
import tarfile
import gzip
from io import BytesIO

# Path to your .tar file
tar_file_path = '/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/GSE201446_RAW.tar'

# Path to your Excel sheet
excel_file_path = '/home/nikvaku/snic2022-6-312/LabMemberScratchDir/Nikhilesh/Raw_data/Supplementary.xlsx'

# Function to read gzipped text content
def read_gzipped_text(file):
    with gzip.open(file, 'rt') as f:
        content = f.read()
    return content

# Function to load counts from a gzipped text file
def load_counts(file_content):
    # Read the gzipped content into a DataFrame
    member_counts_df = pd.read_csv(BytesIO(gzip.decompress(file_content)), sep='\t', index_col=0)
    
    # Transpose the DataFrame to have samples as columns
    member_counts_df = member_counts_df.T
    
    return member_counts_df

# Load tissue_barcode info from the Excel sheet
tissue_barcode_df = pd.read_excel(excel_file_path)

# Create an empty DataFrame to store counts data
counts_df = pd.DataFrame()

# Load counts from individual files in the tar archive
with tarfile.open(tar_file_path, 'r') as tar:
    # List all file names in the tar archive
    file_names = tar.getnames()
    
    # Filter files based on the pattern
    relevant_files = [file_name for file_name in file_names if file_name.endswith('.txt.gz')]
    
    # Loop through relevant files and load counts
    for file_name in relevant_files:
        # Extract the file content
        file_content = tar.extractfile(file_name).read()
        
        # Extract the sample ID from the file name
        sample_id = file_name.split('_')[1].split('.')[0]
        
        # Load counts into a DataFrame
        member_counts_df = load_counts(file_content)
        
        # Add a column for the sample ID
        member_counts_df['SampleID'] = sample_id
        
        # Concatenate the DataFrame to the main counts DataFrame
        counts_df = pd.concat([counts_df, member_counts_df], ignore_index=True)

# Reset the index of the counts DataFrame
counts_df.reset_index(drop=True, inplace=True)

# Create an AnnData object for Scanpy
adata = sc.AnnData(X=counts_df.values[:, :-1], obs=tissue_barcode_df)

# Now you can perform various analyses using Scanpy on the 'adata' object
# For example, you can perform clustering, dimensionality reduction, etc.

# Save the AnnData object to a file if needed
# sc.write('your_output.h5ad', adata)
